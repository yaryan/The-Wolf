# %%
import pandas as pd

# %%
appl = pd.read_csv("full_history/AAPL.csv")

# %%
appl.head()
# Out:
#          date        open        high         low       close   adj close  \
# 0  2023-12-28  194.139999  194.660004  193.169998  193.580002  193.580002
# 1  2023-12-27  192.490005  193.500000  191.089996  193.149994  193.149994
# 2  2023-12-26  193.610001  193.889999  192.830002  193.050003  193.050003
# 3  2023-12-22  195.179993  195.410004  192.970001  193.600006  193.600006
# 4  2023-12-21  196.100006  197.080002  193.500000  194.679993  194.679993
#
#      volume
# 0  34014500
# 1  48087700
# 2  28919300
# 3  37122800
# 4  46482500

# %%
appl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10852 entries, 0 to 10851
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       10852 non-null  object
#  1   open       10852 non-null  float64
#  2   high       10852 non-null  float64
#  3   low        10852 non-null  float64
#  4   close      10852 non-null  float64
#  5   adj close  10852 non-null  float64
#  6   volume     10852 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 593.6+ KB

# %%
amzn  = pd.read_csv("full_history/AMZN.csv")
amzn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6700 entries, 0 to 6699
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       6700 non-null   object
#  1   open       6700 non-null   float64
#  2   high       6700 non-null   float64
#  3   low        6700 non-null   float64
#  4   close      6700 non-null   float64
#  5   adj close  6700 non-null   float64
#  6   volume     6700 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 366.5+ KB

# %%
nvda = pd.read_csv("full_history/NVDA.csv")
nvda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6275 entries, 0 to 6274
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       6275 non-null   object
#  1   open       6275 non-null   float64
#  2   high       6275 non-null   float64
#  3   low        6275 non-null   float64
#  4   close      6275 non-null   float64
#  5   adj close  6275 non-null   float64
#  6   volume     6275 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 343.3+ KB

# %%
nvda.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'adj close', 'volume'], dtype='object')

# %%
news = pd.read_csv("All_external.csv")
news.info()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 news = pd.read_csv("All_external.csv")
#       2 news.info()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
news.head()
# Out:
#                       Date                                      Article_title  \
# 0  2020-06-05 06:30:54 UTC            Stocks That Hit 52-Week Highs On Friday
# 1  2020-06-03 06:45:20 UTC         Stocks That Hit 52-Week Highs On Wednesday
# 2  2020-05-26 00:30:07 UTC                      71 Biggest Movers From Friday
# 3  2020-05-22 08:45:06 UTC       46 Stocks Moving In Friday's Mid-Day Session
# 4  2020-05-22 07:38:59 UTC  B of A Securities Maintains Neutral on Agilent...
#
#   Stock_symbol                                                Url  \
# 0            A  https://www.benzinga.com/news/20/06/16190091/s...
# 1            A  https://www.benzinga.com/news/20/06/16170189/s...
# 2            A  https://www.benzinga.com/news/20/05/16103463/7...
# 3            A  https://www.benzinga.com/news/20/05/16095921/4...
# 4            A  https://www.benzinga.com/news/20/05/16095304/b...
#
#            Publisher Author Article  Lsa_summary  Luhn_summary  \
# ...

# %%
Appl_news = news[news['Stock_symbol'].str.contains('AAPL', case=False, na=False)]
Appl_news.head()
# Out:
#                          Date  \
# 6680  2020-06-10 07:33:26 UTC
# 6681  2020-06-10 04:14:08 UTC
# 6682  2020-06-10 03:53:47 UTC
# 6683  2020-06-10 03:19:25 UTC
# 6684  2020-06-10 02:27:11 UTC
#
#                                           Article_title Stock_symbol  \
# 6680  Tech Stocks And FAANGS Strong Again To Start D...         AAPL
# 6681      10 Biggest Price Target Changes For Wednesday         AAPL
# 6682  Benzinga Pro's Top 5 Stocks To Watch For Wed.,...         AAPL
# 6683  Deutsche Bank Maintains Buy on Apple, Raises P...         AAPL
# 6684  Apple To Let Users Trade In Their Mac Computer...         AAPL
#
#                                                     Url          Publisher  \
# 6680  https://www.benzinga.com/government/20/06/1622...         JJ Kinahan
# 6681  https://www.benzinga.com/analyst-ratings/price...         Lisa Levin
# 6682  https://www.benzinga.com/short-sellers/20/06/1...  Benzinga Newsdesk
# ...

# %%
Appl_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 473 entries, 6680 to 2212401
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              473 non-null    object
#  1   Article_title     473 non-null    object
#  2   Stock_symbol      473 non-null    object
#  3   Url               473 non-null    object
#  4   Publisher         473 non-null    object
#  5   Author            0 non-null      object
#  6   Article           0 non-null      object
#  7   Lsa_summary       0 non-null      float64
#  8   Luhn_summary      0 non-null      float64
#  9   Textrank_summary  0 non-null      float64
#  10  Lexrank_summary   0 non-null      float64
# dtypes: float64(4), object(7)
# memory usage: 44.3+ KB

# %%
file_path = '/Users/yashaswiaryan/Downloads/nasdaq_exteral_data.csv'
news_comp = pd.read_csv(file_path, chunksize=1000)
news_comp.head
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
chunks.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 chunks.columns
#
# AttributeError: 'TextFileReader' object has no attribute 'columns'
